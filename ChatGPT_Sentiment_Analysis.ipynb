# %%
import re
import string


import nltk
from nltk.probability import FreqDist
from nltk.stem import WordNetLemmatizer
from nltk.corpus import stopwords
stemmer =  nltk.SnowballStemmer("english")
from nltk import pos_tag
from nltk.stem import WordNetLemmatizer
from nltk.tokenize import word_tokenize
from sklearn.feature_extraction.text import CountVectorizer

from wordcloud import WordCloud
from tqdm.auto import tqdm
import matplotlib.style as style
style.use('fivethirtyeight')
stopwords = set(stopwords.words('english'))

import warnings
warnings.filterwarnings("ignore")
import pandas as pd
from textblob import TextBlob

from nltk.sentiment.vader import SentimentIntensityAnalyzer
nltk.download('vader_lexicon')
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/anshita/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# True

# %%
from textblob import TextBlob
df = pd.read_csv('tweets.csv',encoding = 'utf8')
df.head()
text_data = df['text']

text_data
# Out:
# 0         MathGPT\n\nUse GPT3 to solve math problems, an...
# 1         chat gpt it's a marvel of technology.\nthose m...
# 2         One thing that's scary is science gathers know...
# 3         @BardAiGoogle #CannabisCommunity \n #Developer...
# 4         Fake Reality: Video Game "Loss"\nReality: Juve...
#                                 ...
# 267078    Levels🙏🙏🙏,so happy for the chatGPT team for co...
# 267079    Iterating back-and-forth with tools like #Chat...
# 267080    Russel vs ChatGPT. It's also funny that it tak...
# 267081    Was just wondering is there any difference bet...
# 267082    #ChatGPT and similar #LLM pose a challenge to ...
# Name: text, Length: 267083, dtype: object

# %%
# Check for missing values and replace them with an empty string
text_data = text_data.fillna('')

# %%
# Initialize the VADER model
sia = SentimentIntensityAnalyzer()

# %%
# Perform sentiment analysis on the text data
sentiment_scores = []
for text in text_data:
    score = sia.polarity_scores(text)['compound']
    sentiment_scores.append(score)

# %%
# Add the sentiment scores as a new column in the DataFrame
df['sentiment_score'] = sentiment_scores

# %%
# Print the DataFrame
df.head()
# Out:
#             user_name                                               text  \
# 0   AGI.Eth | MTL.Eth  MathGPT\n\nUse GPT3 to solve math problems, an...
# 1           Bogo vlog  chat gpt it's a marvel of technology.\nthose m...
# 2     Leeyen Hazarika  One thing that's scary is science gathers know...
# 3        Alan Challis  @BardAiGoogle #CannabisCommunity \n #Developer...
# 4  Beat The Appraiser  Fake Reality: Video Game "Loss"\nReality: Juve...
#
#       user_location                                   user_description  \
# 0  Montréal, Québec  VINCENTBOUCHER.Eth | President at @Montreal_AI...
# 1               NaN                                      okay let's go
# 2               NaN                  District Transport Officer, Assam
# 3          Delaware                                 Love domain names!
# 4               NaN  Value Truth. Accurate measurement AND independ...
#
#                 user_created user_followers user_friends user_favourites  \
# 0  2010-08-09 20:29:17+00:00       155942.0       2607.0          196358
# 1  2023-01-24 05:34:06+00:00           11.0         20.0              55
# 2  2011-01-07 10:59:18+00:00          634.0         75.0              82
# 3  2016-08-25 20:21:58+00:00          275.0       1264.0             947
# 4  2021-08-04 16:48:42+00:00          201.0        977.0             636
#
#   user_verified                       date  \
# 0         False  2023-02-24 15:39:55+00:00
# 1         False  2023-02-24 15:39:53+00:00
# 2         False  2023-02-24 15:39:46+00:00
# 3         False  2023-02-24 15:39:27+00:00
# 4         False  2023-02-24 15:39:23+00:00
#
#                                             hashtags              source  \
# 0                                                NaN  Twitter for iPhone
# 1                             ['ChatGPT', 'chatbot']    Twitter for iPad
# 2                        ['AI', 'ChatGPT', 'OpenAI']     Twitter Web App
# 3  ['CannabisCommunity', 'DeveloperStudentClubs',...     Twitter Web App
# 4                 ['ai', 'chatgpt', 'ar', 'REALITY']  Twitter for iPhone
#
#    sentiment_score
# 0           0.1027
# 1           0.6096
# 2           0.0516
# 3           0.6249
# 4          -0.7579

# %%
text_d = df['sentiment_score']
# Check for missing values and replace them with an empty string
text_d = text_data.fillna('')

# %%
sia = SentimentIntensityAnalyzer()

sentiments = []
for text in text_d:
    score = sia.polarity_scores(text)['compound']
    if score > 0.05:
        sentiments.append('positive')
    elif score < -0.05:
        sentiments.append('negative')
    else:
        sentiments.append('neutral')

# %%
# Add the sentiments as a new column in the DataFrame
df['sentiment'] = sentiments

# %%
# Print the DataFrame
df.head()
# Out:
#             user_name                                               text  \
# 0   AGI.Eth | MTL.Eth  MathGPT\n\nUse GPT3 to solve math problems, an...
# 1           Bogo vlog  chat gpt it's a marvel of technology.\nthose m...
# 2     Leeyen Hazarika  One thing that's scary is science gathers know...
# 3        Alan Challis  @BardAiGoogle #CannabisCommunity \n #Developer...
# 4  Beat The Appraiser  Fake Reality: Video Game "Loss"\nReality: Juve...
#
#       user_location                                   user_description  \
# 0  Montréal, Québec  VINCENTBOUCHER.Eth | President at @Montreal_AI...
# 1               NaN                                      okay let's go
# 2               NaN                  District Transport Officer, Assam
# 3          Delaware                                 Love domain names!
# 4               NaN  Value Truth. Accurate measurement AND independ...
#
#                 user_created user_followers user_friends user_favourites  \
# 0  2010-08-09 20:29:17+00:00       155942.0       2607.0          196358
# 1  2023-01-24 05:34:06+00:00           11.0         20.0              55
# 2  2011-01-07 10:59:18+00:00          634.0         75.0              82
# 3  2016-08-25 20:21:58+00:00          275.0       1264.0             947
# 4  2021-08-04 16:48:42+00:00          201.0        977.0             636
#
#   user_verified                       date  \
# 0         False  2023-02-24 15:39:55+00:00
# 1         False  2023-02-24 15:39:53+00:00
# 2         False  2023-02-24 15:39:46+00:00
# 3         False  2023-02-24 15:39:27+00:00
# 4         False  2023-02-24 15:39:23+00:00
#
#                                             hashtags              source  \
# 0                                                NaN  Twitter for iPhone
# 1                             ['ChatGPT', 'chatbot']    Twitter for iPad
# 2                        ['AI', 'ChatGPT', 'OpenAI']     Twitter Web App
# 3  ['CannabisCommunity', 'DeveloperStudentClubs',...     Twitter Web App
# 4                 ['ai', 'chatgpt', 'ar', 'REALITY']  Twitter for iPhone
#
#    sentiment_score sentiment
# 0           0.1027  positive
# 1           0.6096  positive
# 2           0.0516  positive
# 3           0.6249  positive
# 4          -0.7579  negative
